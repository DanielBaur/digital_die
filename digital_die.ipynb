# %% [markdown]
# <h1><center> project: digital_die </center></h1>
# <br>
# <br>
# <br>
#
# Last Modified: By Daniel Baur on 25th February 2021
#
# This notebook is meant to provide documentation on the ``digital_die`` project. Its ambition is to set up a microcontroller installation of a die.
#
#
#
# <br>
# <br>
#
# ### Table of Contents
#
# 1. **[Resources](#1.-Resources)**<br>
#
#
# 2. **[Breadboard Installation](#2.-Breadboard-Installation)**<br>
#     2.1 [Parts List](#2.1-Parts-List)<br>
#     2.2 [Wiring](#2.2-Wiring)<br>
#     2.3 [Code](#2.3-Code)
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# # 1. Resources
#
# <br>
# <br>
#
# Hier könnte Ihre Werbung stehen.
#
# <br>
# <br>
# <br>
# <br>
# <br>
#
# # 2. Breadboard Installation
#
# <br>
# <br>
#
# ## 2.1 Parts List
#
# Find below a list of the required components along with the corresponding [Conrad links]().
#
# * Hier könnte Ihre Werbung stehen.
#
# Neglecting the costs for the 3D-print the items above add up to 24.71€
#
# <br>
# <br>
#
# ## 2.2 Wiring
#
# <br>
#
# ![breadboard_installation_crop.jpg](attachment:breadboard_installation_crop.jpg)
#
# <br>
# <br>
#
# ## 2.3 Code
#
# <br>
# <br>
# <br>
# <br>
# <br>
#
# # 3. Dead Bug Installation
#
# <br>
# <br>
#
# Hier könnte Ihre Werbung stehen.
#
# <br>
# <br>
# <br>
# <br>
# <br>
